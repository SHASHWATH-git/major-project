# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
data1=load_iris()
x=data1.data
y=data1.target

# %%
wcss=[]
for i in range(2,11):
    model=KMeans(n_clusters=i)
    model.fit(x)
    wcss.append(model.inertia_)
# Out:
# /home/shreyank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/shreyank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/shreyank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /home/shreyank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
plt.plot(range(2, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
model=KMeans(n_clusters=3)
model.fit(x)
# Out:
# /home/shreyank/.local/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
from sklearn.metrics import completeness_score
print("the completeness score : ",completeness_score(y,model.labels_))
# Out:
# the completeness score :  0.7649861514489816

# %%
print(data1['feature_names'])
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
import numpy as np
colormap=np.array(['red','green','yellow'])
plt.figure(figsize=(21,7))
plt.subplot(1,3,1)

plt.scatter(x[:,2],x[:,3],c=colormap[y])
plt.subplot(1,3,2)
plt.scatter(x[:,2],x[:,3],c=colormap[model.labels_])
plt.subplot(1,3,3)
from sklearn.mixture import GaussianMixture
model1=GaussianMixture()
print(inspect.signature(GaussianMixture))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[101], line 8
#       6 plt.scatter(x[:,2],x[:,3],c=colormap[y])
#       7 plt.subplot(1,3,2)
# ----> 8 plt.scatter(x[:,2],x[:,3],c=colormap[model.labels_])
#       9 plt.subplot(1,3,3)
#      10 from sklearn.mixture import GaussianMixture
#
# AttributeError: 'GaussianMixture' object has no attribute 'labels_'
